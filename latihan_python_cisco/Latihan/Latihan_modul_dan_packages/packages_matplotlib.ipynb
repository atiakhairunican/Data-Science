# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
import numpy as np

# %%
# prepare the data
x = np.linspace(0, 10)

# Plot the data
plt.plot(x, x, label = "liniar")

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Initialize the plot
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# or replace thethree lines of code above by the following line:
# fig, (ax1, ax2) = plt.subplots(1,2, figsize(20,10))

# Plot the data
ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

# Show the plot
plt.show()

# %%
# Initialize the plot
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(111)
ax2 = fig.add_subplot(222)

# or replace thethree lines of code above by the following line:
# fig, (ax1, ax2) = plt.subplots(1,2, figsize(20,10))

# Plot the data
ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

# Show the plot
plt.show()

# %%
# Initialize the plot
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

# or replace thethree lines of code above by the following line:
# fig, (ax1, ax2) = plt.subplots(1,2, figsize(20,10))

# Plot the data
ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

# Nambah garis
ax1.axvline(0.65)
ax2.axhline(0.45)

ax3.scatter([1,2,3],[3,4,5])

# Show the plot
plt.show()

# Save the plot
# Save the figure
plt.savefig("foo.png")

# Save transparant figure
plt.savefig("foo tp.png", Transparant=True)

# %%
df_id = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_id.csv')
df_total = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_total.csv')
df_global = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_global.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-87f8a05f8b2a> in <module>
#       1 df_id = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_id.csv')
#       2 df_total = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_total.csv')
# ----> 3 df_global = pd.read_csv(r'C:\Users\HP\python\pembelajaran\latihan_python_cisco\Latihan\Latihan_lainnya\data_covid_global.csv')
#
# ...
